# %%
import pandas as pd

# %%
# to find data file useing read 
df = pd.read_csv(r"D:\data_science\pandas\laptop\laptopPrice.csv")

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# ...

# %%
df.tail()
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd   hdd       os  os_bit graphic_card_gb      weight     warranty  \
# 818  1024 GB  0 GB  Windows  64-bit            0 GB      Casual       1 year
# 819  1024 GB  0 GB  Windows  64-bit            0 GB      Casual       1 year
# 820  1024 GB  0 GB  Windows  64-bit            4 GB      Casual       1 year
# 821  1024 GB  0 GB  Windows  64-bit            4 GB      Casual       1 year
# 822   512 GB  0 GB      DOS  64-bit            0 GB  ThinNlight  No warranty
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %%
df.columns
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'Price', 'rating',
#        'Number of Ratings', 'Number of Reviews'],
#       dtype='object')

# %%
#value  of rating or key points /max value/min value
df.describe()
# Out:
#                Price  Number of Ratings  Number of Reviews
# count     823.000000         823.000000         823.000000
# mean    76745.177400         315.301337          37.609964
# std     45101.790525        1047.382654         121.728017
# min     16990.000000           0.000000           0.000000
# 25%     46095.000000           0.000000           0.000000
# 50%     64990.000000          17.000000           2.000000
# 75%     89636.000000         139.500000          18.000000
# max    441990.000000       15279.000000        1947.000000

# %%
# iska use tume kis type ka data extract karna uske liye karte hai jes int ,object (string,char),float
df.select_dtypes
# Out:
# <bound method DataFrame.select_dtypes of       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
all_new_brands = df['brand'].unique()
all_new_brands
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
#yah o ki jagh par float ya int bhi likh sakte ho
cat_column = df.select_dtypes(include='O') # yaha O ka matlab object hai to yah ise strin value hi print ho rhi hai chai char valu thodi bhi hogi to bo print hoga 
cat_column
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %% [markdown]
# ### iske niche jo csv file me jo bhi brand hai unke name hai

# %%
cat_column['brand'].unique() # uniqe parmeterr ka use is liye hota hai ki usme kitne alag alag name hi ya uniqe hai naa ki same
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
cat_column['processor_brand'].unique()
# Out:
# array(['Intel', 'AMD', 'M1'], dtype=object)

# %%
cat_column['processor_name'].unique()
# Out:
# array(['Core i3', 'Core i5', 'Celeron Dual', 'Ryzen 5', 'Core i7',
#        'Core i9', 'M1', 'Pentium Quad', 'Ryzen 3', 'Ryzen 7', 'Ryzen 9'],
#       dtype=object)

# %%
cat_column['processor_gnrtn'].unique()
# Out:
# array(['10th', 'Not Available', '11th', '7th', '8th', '9th', '4th',
#        '12th'], dtype=object)

# %%
cat_column['ram_gb'].unique()
# Out:
# array(['4 GB', '8 GB', '16 GB', '32 GB'], dtype=object)

# %%
cat_column['ram_type'].unique()
# Out:
# array(['DDR4', 'LPDDR4', 'LPDDR4X', 'DDR5', 'DDR3', 'LPDDR3'],
#       dtype=object)

# %%
cat_column['os_bit'].unique()
# Out:
# array(['64-bit', '32-bit'], dtype=object)

# %%
cat_column['os'].unique()
# Out:
# array(['Windows', 'DOS', 'Mac'], dtype=object)

# %%
cat_column['msoffice'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
cat_column['hdd'].unique()
# Out:
# array(['1024 GB', '0 GB', '512 GB', '2048 GB'], dtype=object)

# %%
cat_column['graphic_card_gb'].unique()
# Out:
# array(['0 GB', '2 GB', '4 GB', '6 GB', '8 GB'], dtype=object)

# %%
cat_column['Touchscreen'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %% [markdown]
# ### iske niche jo bhi value hai sab barnd hai unke number value ko caunt kar rha hai

# %%
cat_column['brand'].nunique() # iska use jo bhi unique name hai bo kitane hai unka count ke liye use karte hai iska nunique ka
# Out:
# 8

# %%
cat_column['processor_brand'].nunique()
# Out:
# 3

# %%
cat_column['processor_name'].nunique()
# Out:
# 11

# %%
cat_column['processor_gnrtn'].nunique()
# Out:
# 8

# %%
cat_column['ram_gb'].nunique()
# Out:
# 4

# %%
cat_column['ram_type'].nunique()
# Out:
# 6

# %%
cat_column['os_bit'].nunique()
# Out:
# 2

# %%
cat_column['os'].nunique()
# Out:
# 3

# %%
cat_column['msoffice'].nunique()
# Out:
# 2

# %%
cat_column['hdd'].nunique()
# Out:
# 4

# %%
cat_column['graphic_card_gb'].nunique()
# Out:
# 5

# %%
cat_column['Touchscreen'].nunique()
# Out:
# 2

# %%
df['brand'].value_counts()
# Out:
# brand
# ASUS      249
# DELL      151
# Lenovo    144
# HP        136
# acer       51
# MSI        50
# APPLE      28
# Avita      14
# Name: count, dtype: int64

# %%
df.info
# Out:
# <bound method DataFrame.info of       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %% [markdown]
# <img src="https://th.bing.com/th/id/OIP.847qCXl2CDqca-8gHr_RKQHaHa?w=1000&h=1000&rs=1&pid=ImgDetMain" width="250">

# %%
# ya df bo hai jo hamne pahle hi data set ki loction store ki hue hai 
#or ham yaha usme se jo brand bala columns hai uske under se APPLE bale brand ko hi extrack karne ke liye
apple = df[df['brand']== "APPLE"]

# %%
apple
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 309  APPLE           Intel        Core i5            10th   8 GB  LPDDR4X
# 310  APPLE           Intel        Core i5             8th   8 GB     DDR3
# 407  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 408  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 599  APPLE              M1             M1            10th   8 GB     DDR4
# 600  APPLE              M1             M1            10th   8 GB     DDR4
# 601  APPLE              M1             M1            10th  16 GB     DDR4
# 602  APPLE              M1             M1            10th   8 GB     DDR4
# 603  APPLE              M1             M1            10th  16 GB     DDR4
# 604  APPLE              M1             M1            10th  16 GB     DDR4
# 605  APPLE              M1             M1            10th   8 GB     DDR4
# 606  APPLE              M1             M1            10th  16 GB     DDR4
# ...

# %%
apple['processor_brand'].unique() #iska use uske column ke unde kitne uniqe name hai
# Out:
# array(['Intel', 'M1'], dtype=object)

# %%
apple['processor_brand'].nunique() # uqique kitni hai ukse liye
# Out:
# 2

# %%
apple_m1_chip = apple[apple['processor_brand']=='M1'] # isme ham jo brand bal column hai usme se m1 chip balo ko hi print kar ba rhe hai ya extract kar rahe hai

# %%
apple_m1_chip
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 599  APPLE              M1             M1            10th   8 GB     DDR4
# 600  APPLE              M1             M1            10th   8 GB     DDR4
# 601  APPLE              M1             M1            10th  16 GB     DDR4
# 602  APPLE              M1             M1            10th   8 GB     DDR4
# 603  APPLE              M1             M1            10th  16 GB     DDR4
# 604  APPLE              M1             M1            10th  16 GB     DDR4
# 605  APPLE              M1             M1            10th   8 GB     DDR4
# 606  APPLE              M1             M1            10th  16 GB     DDR4
# 607  APPLE              M1             M1            10th   8 GB     DDR4
# 608  APPLE              M1             M1            10th   8 GB     DDR4
# 609  APPLE              M1             M1            10th   8 GB     DDR4
# 610  APPLE              M1             M1            10th   8 GB     DDR4
# ...

# %%
apple_intel_chip = apple[apple['processor_brand']=='Intel']

# %%
apple_intel_chip
# Out:
#      brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 309  APPLE           Intel        Core i5            10th   8 GB  LPDDR4X
# 310  APPLE           Intel        Core i5             8th   8 GB     DDR3
# 407  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
# 408  APPLE           Intel        Core i5            10th  16 GB  LPDDR4X
#
#          ssd   hdd   os  os_bit graphic_card_gb  weight warranty Touchscreen  \
# 309   512 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
# 310   512 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
# 407  1024 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
# 408  1024 GB  0 GB  Mac  64-bit            0 GB  Casual   1 year          No
#
#     msoffice   Price   rating  Number of Ratings  Number of Reviews
# 309       No  159990  4 stars                 32                  5
# 310       No  172090  4 stars                108                 13
# ...

# %%
apple_m1_touchscreen = apple[apple['Touchscreen']=='Yes']

# %%
apple_m1_touchscreen
# Out:
# Empty DataFrame
# Columns: [brand, processor_brand, processor_name, processor_gnrtn, ram_gb, ram_type, ssd, hdd, os, os_bit, graphic_card_gb, weight, warranty, Touchscreen, msoffice, Price, rating, Number of Ratings, Number of Reviews]
# Index: []

# %%
apple.max()
# Out:
# brand                  APPLE
# processor_brand           M1
# processor_name            M1
# processor_gnrtn          8th
# ram_gb                  8 GB
# ram_type             LPDDR4X
# ssd                   512 GB
# hdd                     0 GB
# os                       Mac
# os_bit                64-bit
# graphic_card_gb         0 GB
# weight                Casual
# warranty              1 year
# Touchscreen               No
# msoffice                  No
# Price                 309990
# rating               5 stars
# Number of Ratings       6725
# Number of Reviews        629
# dtype: object

# %%
apple_m1_chip.max()
# Out:
# brand                  APPLE
# processor_brand           M1
# processor_name            M1
# processor_gnrtn         10th
# ram_gb                  8 GB
# ram_type                DDR4
# ssd                   512 GB
# hdd                     0 GB
# os                       Mac
# os_bit                64-bit
# graphic_card_gb         0 GB
# weight                Casual
# warranty              1 year
# Touchscreen               No
# msoffice                  No
# Price                 309990
# rating               5 stars
# Number of Ratings       6725
# Number of Reviews        629
# dtype: object

# %%
apple_intel_chip.min()
# Out:
# brand                  APPLE
# processor_brand        Intel
# processor_name       Core i5
# processor_gnrtn         10th
# ram_gb                 16 GB
# ram_type                DDR3
# ssd                  1024 GB
# hdd                     0 GB
# os                       Mac
# os_bit                64-bit
# graphic_card_gb         0 GB
# weight                Casual
# warranty              1 year
# Touchscreen               No
# msoffice                  No
# Price                 159990
# rating               4 stars
# Number of Ratings         31
# Number of Reviews          3
# dtype: object

# %% [markdown]
# <img src="https://images.fonearena.com/blog/wp-content/uploads/2023/12/acer-logo-1024x381.png" width="250px">

# %%
acer = df[df['brand']== "acer"]

# %%
acer
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 9    acer             AMD        Ryzen 5            10th   4 GB     DDR4
# 10   acer             AMD        Ryzen 5            10th   4 GB     DDR4
# 11   acer             AMD        Ryzen 5            10th   4 GB     DDR4
# 31   acer           Intel        Core i3            11th   8 GB     DDR4
# 64   acer           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 161  acer           Intel        Core i3            11th   4 GB     DDR4
# 176  acer           Intel        Core i3            11th   8 GB     DDR4
# 196  acer           Intel        Core i5   Not Available   8 GB     DDR5
# 197  acer           Intel        Core i5   Not Available   8 GB   LPDDR4
# 198  acer           Intel        Core i5            10th   8 GB   LPDDR4
# 207  acer           Intel        Core i5             7th   8 GB     DDR3
# 210  acer           Intel        Core i5             8th   8 GB     DDR3
# ...

# %%
acer_graphic_card = acer[acer['graphic_card_gb']=='4 GB']

# %%
acer_graphic_card
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 9    acer             AMD        Ryzen 5            10th   4 GB     DDR4
# 11   acer             AMD        Ryzen 5            10th   4 GB     DDR4
# 196  acer           Intel        Core i5   Not Available   8 GB     DDR5
# 325  acer           Intel        Core i5             8th   8 GB     DDR4
# 585  acer           Intel        Core i7            11th  16 GB     DDR4
# 780  acer             AMD        Ryzen 7   Not Available   4 GB     DDR4
# 794  acer             AMD        Ryzen 7   Not Available  16 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 9       0 GB   512 GB  Windows  32-bit            4 GB  Casual  No warranty
# 11      0 GB   512 GB  Windows  32-bit            4 GB  Casual  No warranty
# 196     0 GB   512 GB  Windows  32-bit            4 GB  Casual  No warranty
# 325   512 GB     0 GB  Windows  64-bit            4 GB  Casual       1 year
# ...

# %%
acer_touchscreen = acer_graphic_card[acer_graphic_card['Touchscreen']=='Yes']

# %%
acer_touchscreen
# Out:
# Empty DataFrame
# Columns: [brand, processor_brand, processor_name, processor_gnrtn, ram_gb, ram_type, ssd, hdd, os, os_bit, graphic_card_gb, weight, warranty, Touchscreen, msoffice, Price, rating, Number of Ratings, Number of Reviews]
# Index: []

# %%
acer_touchscreen_yes = acer[acer['Touchscreen']=='Yes']

# %%
acer_touchscreen_yes
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 210  acer           Intel        Core i5             8th   8 GB     DDR3
# 365  acer           Intel        Core i5            11th   8 GB     DDR4
#
#         ssd   hdd       os  os_bit graphic_card_gb      weight     warranty  \
# 210  256 GB  0 GB  Windows  64-bit            0 GB  ThinNlight       1 year
# 365  512 GB  0 GB  Windows  64-bit            0 GB  ThinNlight  No warranty
#
#     Touchscreen msoffice   Price   rating  Number of Ratings  \
# 210         Yes      Yes   81998  4 stars                 14
# 365         Yes       No  109999  3 stars                  0
#
#      Number of Reviews
# 210                  3
# 365                  0

# %% [markdown]
# <img src="https://logos-world.net/wp-content/uploads/2020/07/Asus-Logo-1995-present.png" width = "250px">

# %%
asus = df[df['brand']== "ASUS"]

# %%
asus
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 5    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 6    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..    ...             ...            ...             ...    ...      ...
# 817  ASUS             AMD        Ryzen 9   Not Available   4 GB  LPDDR4X
# 818  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821  ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# ...

# %%
asus_10thgen = asus[asus['processor_gnrtn']=='10th']

# %%
asus_10thgen
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 7    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 27   ASUS           Intel        Core i3            10th   8 GB     DDR4
# 60   ASUS           Intel        Core i3            10th   4 GB     DDR4
# 70   ASUS           Intel        Core i3            10th   4 GB     DDR4
# 86   ASUS           Intel        Core i3            10th   8 GB     DDR4
# 89   ASUS           Intel        Core i3            10th   4 GB     DDR4
# 98   ASUS           Intel        Core i3            10th   4 GB     DDR4
# 119  ASUS           Intel        Core i3            10th   4 GB     DDR4
# 120  ASUS           Intel        Core i3            10th   4 GB     DDR4
# 122  ASUS           Intel        Core i3            10th   4 GB     DDR4
# ...

# %%
asus_ram = asus_10thgen[asus_10thgen['ram_type']=='LPDDR3']

# %%
asus_ram
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 302  ASUS           Intel        Core i5            10th   8 GB   LPDDR3
# 381  ASUS           Intel        Core i5            10th   8 GB   LPDDR3
# 382  ASUS           Intel        Core i5            10th   8 GB   LPDDR3
# 386  ASUS           Intel        Core i5            10th   8 GB   LPDDR3
# 541  ASUS           Intel        Core i7            10th  16 GB   LPDDR3
# 565  ASUS           Intel        Core i7            10th  16 GB   LPDDR3
# 566  ASUS           Intel        Core i7            10th  16 GB   LPDDR3
# 568  ASUS           Intel        Core i7            10th  16 GB   LPDDR3
# 576  ASUS           Intel        Core i7            10th  16 GB   LPDDR3
#
#          ssd   hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 302   512 GB  0 GB  Windows  64-bit            0 GB  Casual       1 year
# 381   512 GB  0 GB  Windows  64-bit            2 GB  Casual       1 year
# ...

# %%
asus_graphic_card_gb = asus_ram[asus_ram['graphic_card_gb']=='4 GB']

# %%
asus_graphic_card_gb
# Out:
# Empty DataFrame
# Columns: [brand, processor_brand, processor_name, processor_gnrtn, ram_gb, ram_type, ssd, hdd, os, os_bit, graphic_card_gb, weight, warranty, Touchscreen, msoffice, Price, rating, Number of Ratings, Number of Reviews]
# Index: []

# %% [markdown]
# <img src="https://d3atsf3fgek2rw.cloudfront.net/content/uploads/2015/05/branding_image-logo_lenovoimageenergy_low_res.jpg" width="250">

# %%
lenovo = df[df['brand']== "Lenovo"]

# %%
lenovo
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 8    Lenovo           Intel        Core i5            10th   4 GB     DDR4
# 17   Lenovo           Intel   Celeron Dual   Not Available   4 GB     DDR4
# 19   Lenovo           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 771  Lenovo             AMD        Ryzen 7   Not Available  16 GB     DDR4
# 784  Lenovo             AMD        Ryzen 7   Not Available   4 GB     DDR4
# 787  Lenovo             AMD        Ryzen 7   Not Available   4 GB     DDR4
# 795  Lenovo             AMD        Ryzen 7   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...
